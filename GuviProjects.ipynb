# %%
pip install kaggle
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import kaggle

# %%
#download the retail order dataset from Kaggle API
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 255kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 254kB/s]

# %%
#path to download the zipfile
zip_file_path = "orders.csv.zip"  #"C:\Users\Balasaravanamuthu\orders.csv.zip"

# %%
#extract csv file from zipfile
with zipfile.ZipFile(zip_file_path,'r') as zip_ref:
    zip_ref.extractall()
    zip_ref.close()
print("Extract done")
# Out:
# Extract done

# %%
import pandas as pd

# %%
#read data from file
csv_file_path = "orders.csv"
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#Data cleaning
#renaming columns by convert it to lower case and replace space with character
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
#remove trailing spaces
df = df.apply(lambda x: x.str.strip() if x.dtype == 'object' else x)

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
#derive new columns discount , sale price and profit
df['discount']=df['list_price']*df['discount_percent']*.01
df['sale_price']= df['list_price']-df['discount']
df['profit']=df['sale_price']-df['cost_price']

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
#split the data frame into 2 data frame for making it as primary and foreign key
df_orders = df[['order_id','order_date','ship_mode','segment','country','city','state','postal_code','region']]
df_order_details = df[['order_id','category','sub_category','product_id','cost_price','list_price','quantity','discount_percent','discount','sale_price','profit']]

# %%
df_orders
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region
# 0           Henderson    Kentucky        42420  South
# ...

# %%
df_order_details
# Out:
#       order_id         category sub_category       product_id  cost_price  \
# 0            1        Furniture    Bookcases  FUR-BO-10001798         240
# 1            2        Furniture       Chairs  FUR-CH-10000454         600
# 2            3  Office Supplies       Labels  OFF-LA-10000240          10
# 3            4        Furniture       Tables  FUR-TA-10000577         780
# 4            5  Office Supplies      Storage  OFF-ST-10000760          20
# ...        ...              ...          ...              ...         ...
# 9989      9990        Furniture  Furnishings  FUR-FU-10001889          30
# 9990      9991        Furniture  Furnishings  FUR-FU-10000747          70
# 9991      9992       Technology       Phones  TEC-PH-10003645         220
# 9992      9993  Office Supplies        Paper  OFF-PA-10004041          30
# 9993      9994  Office Supplies   Appliances  OFF-AP-10002684         210
#
#       list_price  quantity  discount_percent  discount  sale_price  profit
# ...

# %%
#Create database
import mysql.connector
from mysql.connector import Error

def create_database():
    try:
        # Connect to the MySQL server 
        connection = mysql.connector.connect(
            host='localhost',  
            user='root',       
            password='T1e2s3t4'  
        )
        
        if connection.is_connected():
            # Create a cursor object to interact with MySQL
            cursor = connection.cursor()
            
            # Create the new database
            cursor.execute("CREATE DATABASE IF NOT EXISTS Retail_Orders")
            print("Database 'Retail_Orders' created successfully.")
            
    except Error as e:
        print(f"Error while creating database: {e}")
    
    finally:
        # Close the connection
        if connection.is_connected():
            cursor.close()
            connection.close()

# Call the function to create the database
create_database()
# Out:
# Database 'Retail_Orders' created successfully.

# %%
#Create 2 tables into mysql
import pymysql

# MySQL connection details
username = 'root' 
password = 'T1e2s3t4'  
database = 'Retail_Orders'  
host = 'localhost'          
port = 3306                

# Connect to MySQL
connection = pymysql.connect(
    host=host,
    user=username,
    password=password,
    database=database,
    port=port
)

# Create cursor object to execute SQL queries
cursor = connection.cursor()

# Create 'orders' table with primary key
create_orders_table = """
CREATE TABLE IF NOT EXISTS orders (
    order_id INT PRIMARY KEY,
    order_date DATE NOT NULL,
    ship_mode VARCHAR(50),
    segment VARCHAR(50),
    country VARCHAR(50),
    city VARCHAR(50),
    state VARCHAR(50),
    postal_code INT,
    region VARCHAR(50)
);
"""

# Create 'products' table with foreign key referencing 'orders' table
create_order_details_table = """
CREATE TABLE IF NOT EXISTS order_details (
    product_id VARCHAR(50),
    order_id INT NOT NULL,
    category VARCHAR(50),
    sub_category VARCHAR(50),
    cost_price DECIMAL(10, 2),
    list_price DECIMAL(10, 2),
    quantity INT,
    discount_percent INT,
    discount INT,
    sale_price DECIMAL(10, 2),
    profit INT,
    FOREIGN KEY (order_id) REFERENCES orders(order_id) 
        ON DELETE CASCADE
        ON UPDATE CASCADE
);
"""

try:
    # Execute the SQL statements to create tables
    cursor.execute(create_orders_table)
    cursor.execute(create_order_details_table)
    
    # Commit changes
    connection.commit()

    print("Tables created successfully with primary and foreign key constraints.")
except Exception as e:
    print(f"Error: {e}")
    connection.rollback()
finally:
    # Close the connection
    cursor.close()
    connection.close()
# Out:
# Tables created successfully with primary and foreign key constraints.

# %%
#Load the 2 dataframe into corresponding tables in mysql
import pandas as pd
from sqlalchemy import create_engine

try:
    username = "root"
    password = "T1e2s3t4"
    host = "localhost"
    port = "3306"
    database = "Retail_Orders"
    connection_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"

    engine = create_engine(connection_string)
    # Insert 'orders' DataFrame
    df_orders.to_sql('orders', con=engine, if_exists='append', index=False)
    
    # Insert 'order details' DataFrame
    df_order_details.to_sql('order_details', con=engine, if_exists='append', index=False)
    
    print("DataFrames inserted into MySQL successfully!")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# DataFrames inserted into MySQL successfully!
